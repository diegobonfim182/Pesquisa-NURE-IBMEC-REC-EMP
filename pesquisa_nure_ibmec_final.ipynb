# %%
#Instalando o Selenium, que é um framework para fazer o webscraping dos dados nas páginas

# %%
# !Pip3 install --user selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.20.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Using cached trio-0.25.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Using cached trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\programdata\anaconda3\lib\site-packages (from selenium) (4.9.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Using cached selenium-4.20.0-py3-none-any.whl (9.5 MB)
# Using cached trio-0.25.0-py3-none-any.whl (467 kB)
# Using cached trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: h11, attrs, wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed attrs-23.2.0 h11-0.14.0 outcome-1.3.0.post0 selenium-4.20.0 trio-0.25.0 trio-websocket-0.11.1 wsproto-1.2.0

# %%
#Web drive manager é utilizado para manipular navegadores

# %%
# !Pip3 install --user webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\programdata\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager) (2024.2.2)
# Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.1

# %%
#Importando os componentes necessários para rodar o projeto

# %%
from selenium import webdriver
#A classe service é usada para iniciar uma instância do Chrome WebDriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.support.relative_locator import locate_with

# %%
#O webdriver.Chrome serve para você não precisar ficar colocando versão do Chrome e em pastas específicas te dando trabalho
#Abre o drive

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
#Chamar o site

# %%
url_site = 'https://scholar.google.com.br/scholar?as_ylo=2020&q=recupera%C3%A7%C3%A3o+judicial&hl=pt-BR&as_sdt=0,5&as_vis=1'

driver.get(url_site)

# %%
palavras_chaves = input("Digite a palavra chave a ser utilizada: ")
print(f'\n  A palavra chave é: "{palavras_chaves}"')
# Out:
# Digite a palavra chave a ser utilizada:  empresas
#   A palavra chave é: "empresas"

# %%
#Aqui é onde vai ficar o loop
#De toda forma já vai pegar a palavra chave e vai procurar na nova página

# %%
elemento = driver.find_element(By.PARTIAL_LINK_TEXT, palavras_chaves)
elemento
html_print = elemento.get_attribute("outerHTML")
html_print
# Out:
# '<a id="8naXijlQifcJ" href="https://trilhasdahistoria.ufms.br/index.php/deson/article/view/7779" data-clk="hl=pt-BR&amp;sa=T&amp;ct=res&amp;cd=3&amp;d=17836876007246100210&amp;ei=lQNDZrvwJ8uNy9YP56KMyA4" data-clk-atid="8naXijlQifcJ">Gerenciamento de resultados em empresas brasileiras nos anos antecedentes ao pedido de <b>recuperação judicial </b>ou falência</a>'

# %%
#Abaixo foi colocado um if else com o find com a condição -1 que indica quando nada é encontrado

# %%
url_pagina1 = 'https://scholar.google.com.br/scholar?start=10&q=recupera%C3%A7%C3%A3o+judicial&hl=pt-BR&as_sdt=0,5&as_ylo=2020&as_vis=1' 
lista_ids_coletados = []
resultado = html_print.find(palavras_chaves)
start = 2

while start > 1:
        url_presente = driver.current_url
        elements = driver.find_elements(By.PARTIAL_LINK_TEXT, palavras_chaves)
        print(f'Itens achados com a PALAVRA-CHAVE:  "{palavras_chaves}" \n')
        print(f'Número de itens achados no index: "{len(elements)}" \n')
        print(f'Substring achados no index:, "{resultado}" \n')
        print("------------------------------------------------")
        print(f"Artigos encontrados: \n")
        for e in elements:
            print(f'-"{e.text}" ; \n')
        print("------------------------------------------------")
        print(f'ID´s encontrados: \n')
        for e in elements:   
            coletando_id = e.get_attribute('id')
            if coletando_id == "":
                print('-Não tem ID e não serão copiadas')
            else:
               lista_ids_coletados.append(f'a[data-clk-atid="{coletando_id}"]')
               print(f"-{coletando_id} ; \n ")
        print(f'Número de id´s achados no index: "{len(lista_ids_coletados)}" \n ')
        print(f'{lista_ids_coletados} \n ')
        print("------------------------------------------------")
        print(f'Clicks realizados: \n')
       
        print(url_presente_dinamico)
        for e in lista_ids_coletados:
                 url_presente_dinamico = driver.current_url
                 driver.implicitly_wait(5)
                 if url_presente ==  url_presente_dinamico :
                    print("Status ok! \n")
                    print(e)
                    elemento4 = driver.find_element(By.CSS_SELECTOR, e)
                    elemento4.click()
                    print(f"{elemento4} \n")
                    #driver.get(url_site)
                    driver.implicitly_wait(3)
                    url_presente_dinamico = driver.current_url
                    if url_presente == url_presente_dinamico:
                        print("Status ok! Pós click \n")
                    else:
                        driver.back()
                        print("Entrou em um link e necessitou de retroceder! \n")
                 else:    
                    driver.back()
                    print("Entrou em um link e necessitou de retroceder! \n")
                    #driver.get(url_site)
                    #driver.back()

        botao_next = driver.find_element(By.CLASS_NAME, "gs_ico_nav_next")
        botao_next.click()
        print(botao_next)

        lista_ids_coletados.clear()
        print(lista_ids_coletados)
# Out:
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "3"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# -"Gerenciamento de resultados em empresas brasileiras nos anos antecedentes ao pedido de recuperação judicial ou falência" ;
#
# -"recuperação judicial empresas" ;
#
# -"Lei nº 11.101/2005: procedimentos da falência, recuperação judicial e recuperação extrajudicial de empresas" ;
#
# ------------------------------------------------
# ID´s encontrados:
#
# -8naXijlQifcJ ;
#
# -Não tem ID e não serão copiadas
# -7Gy9NFFZEuQJ ;
#
# Número de id´s achados no index: "2"
#
# ['a[data-clk-atid="8naXijlQifcJ"]', 'a[data-clk-atid="7Gy9NFFZEuQJ"]']
#
# ------------------------------------------------
# Clicks realizados:
#
# https://scholar.google.com.br/scholar?as_ylo=2020&q=recupera%C3%A7%C3%A3o+judicial&hl=pt-BR&as_sdt=0,5&as_vis=1
# Status ok!
#
# a[data-clk-atid="8naXijlQifcJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.B2CB698F0EB3E622AA307B50B4BCC1DD.e.40")>
#
# Status ok! Pós click
#
# Status ok!
#
# a[data-clk-atid="7Gy9NFFZEuQJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.B2CB698F0EB3E622AA307B50B4BCC1DD.e.41")>
#
# Status ok! Pós click
#
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.B2CB698F0EB3E622AA307B50B4BCC1DD.e.44")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "2"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# -"Quais os principais mecanismos de reorganização adotados pelas empresas brasileiras em recuperação judicial?" ;
#
# -"Custos de transação e informação contábil na recuperação judicial de micro e pequenas empresas" ;
#
# ------------------------------------------------
# ID´s encontrados:
#
# -45YJ0b7VsUAJ ;
#
# -XsEe0tCHr7AJ ;
#
# Número de id´s achados no index: "2"
#
# ['a[data-clk-atid="45YJ0b7VsUAJ"]', 'a[data-clk-atid="XsEe0tCHr7AJ"]']
#
# ------------------------------------------------
# Clicks realizados:
#
# https://scholar.google.com.br/scholar?as_ylo=2020&q=recupera%C3%A7%C3%A3o+judicial&hl=pt-BR&as_sdt=0,5&as_vis=1
# Status ok!
#
# a[data-clk-atid="45YJ0b7VsUAJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.AC91DEB8FEDD3CE9EF2662F888677EA7.e.79")>
#
# Status ok! Pós click
#
# Status ok!
#
# a[data-clk-atid="XsEe0tCHr7AJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.AC91DEB8FEDD3CE9EF2662F888677EA7.e.80")>
#
# Entrou em um link e necessitou de retroceder!
#
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.AC91DEB8FEDD3CE9EF2662F888677EA7.e.83")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "0"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# ------------------------------------------------
# ID´s encontrados:
#
# Número de id´s achados no index: "0"
#
# []
#
# ------------------------------------------------
# Clicks realizados:
#
# https://pco.uem.br/0-arquivos/dissertacoes/2019_fabio-ibanhez-bertuchi.pdf
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.AA6E649B78E6B90A4384F19DE10D4354.e.111")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "3"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# -"A cessão fiduciária de créditos recebíveis nos casos de recuperação judicial de empresas" ;
#
# -"Lei de Falências e recuperação judicial de empresas e as alterações trazidas pela Lei 14.112/20" ;
#
# -"Determinantes de atrasos na votação do plano de recuperação judicial de empresas" ;
#
# ------------------------------------------------
# ID´s encontrados:
#
# -nslq4mDyBsgJ ;
#
# -t-5gFBgoYGQJ ;
#
# -C1DIYvf2CRwJ ;
#
# Número de id´s achados no index: "3"
#
# ['a[data-clk-atid="nslq4mDyBsgJ"]', 'a[data-clk-atid="t-5gFBgoYGQJ"]', 'a[data-clk-atid="C1DIYvf2CRwJ"]']
#
# ------------------------------------------------
# Clicks realizados:
#
# https://pco.uem.br/0-arquivos/dissertacoes/2019_fabio-ibanhez-bertuchi.pdf
# Status ok!
#
# a[data-clk-atid="nslq4mDyBsgJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.6C0D6486BF3ADE748D6B367EEADFC7DF.e.137")>
#
# Entrou em um link e necessitou de retroceder!
#
# Status ok!
#
# a[data-clk-atid="t-5gFBgoYGQJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.6C0D6486BF3ADE748D6B367EEADFC7DF.e.142")>
#
# Entrou em um link e necessitou de retroceder!
#
# Status ok!
#
# a[data-clk-atid="C1DIYvf2CRwJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.6C0D6486BF3ADE748D6B367EEADFC7DF.e.143")>
#
# Entrou em um link e necessitou de retroceder!
#
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.6C0D6486BF3ADE748D6B367EEADFC7DF.e.144")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "0"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# ------------------------------------------------
# ID´s encontrados:
#
# Número de id´s achados no index: "0"
#
# []
#
# ------------------------------------------------
# Clicks realizados:
#
# https://www.scielo.br/j/rbgn/a/ZJgQVMqSWdvWTxbhjxLNGMK/?lang=pt&format=html
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.B836A4A67CECEEC17A9E533E56B8C93F.e.163")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "0"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# ------------------------------------------------
# ID´s encontrados:
#
# Número de id´s achados no index: "0"
#
# []
#
# ------------------------------------------------
# Clicks realizados:
#
# https://www.scielo.br/j/rbgn/a/ZJgQVMqSWdvWTxbhjxLNGMK/?lang=pt&format=html
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.45EAD6F71FEDFB9B9D821ACB4EA67F42.e.184")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "1"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# -"O financiamento de empresas em recuperação judicial no Brasil sob a ótica da lei nº 14.112/20" ;
#
# ------------------------------------------------
# ID´s encontrados:
#
# -xa3Ez33szfsJ ;
#
# Número de id´s achados no index: "1"
#
# ['a[data-clk-atid="xa3Ez33szfsJ"]']
#
# ------------------------------------------------
# Clicks realizados:
#
# https://www.scielo.br/j/rbgn/a/ZJgQVMqSWdvWTxbhjxLNGMK/?lang=pt&format=html
# Status ok!
#
# a[data-clk-atid="xa3Ez33szfsJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.63C8EC85F426E5A0D277750BC29EBB26.e.213")>
#
# Entrou em um link e necessitou de retroceder!
#
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.63C8EC85F426E5A0D277750BC29EBB26.e.216")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "0"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# ------------------------------------------------
# ID´s encontrados:
#
# Número de id´s achados no index: "0"
#
# []
#
# ------------------------------------------------
# Clicks realizados:
#
# https://repositorio.ufc.br/bitstream/riufc/59089/1/2021_tcc_jgfreitasfilho.pdf
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.90B64CB3CBDB6857F1451FA9B4F42DCE.e.244")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "1"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# -"O instituto da mediação nos processos de recuperação judicial de empresas" ;
#
# ------------------------------------------------
# ID´s encontrados:
#
# -6cMAz9x9xsIJ ;
#
# Número de id´s achados no index: "1"
#
# ['a[data-clk-atid="6cMAz9x9xsIJ"]']
#
# ------------------------------------------------
# Clicks realizados:
#
# https://repositorio.ufc.br/bitstream/riufc/59089/1/2021_tcc_jgfreitasfilho.pdf
# Status ok!
#
# a[data-clk-atid="6cMAz9x9xsIJ"]
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.A401F652EAB3064B0E575D575167BCC3.e.273")>
#
# Entrou em um link e necessitou de retroceder!
#
# <selenium.webdriver.remote.webelement.WebElement (session="6f367246c98eda4a392649a0de6e3ae3", element="f.403F6F7D24E04E6C3DBE9AAB3CD0AEF2.d.A401F652EAB3064B0E575D575167BCC3.e.274")>
# []
# Itens achados com a PALAVRA-CHAVE:  "empresas"
#
# Número de itens achados no index: "1"
#
# Substring achados no index:, "263"
#
# ------------------------------------------------
# Artigos encontrados:
#
# -"Recuperação judicial de micro e pequenas empresas: desafios legais e financeiros" ;
#
# ------------------------------------------------
# ID´s encontrados:
#
# -XSdTCOjNGdUJ ;
#
# Número de id´s achados no index: "1"
#
# ['a[data-clk-atid="XSdTCOjNGdUJ"]']
#
# ------------------------------------------------
# Clicks realizados:
#
# https://repositorio.pucgoias.edu.br/jspui/bitstream/123456789/6050/1/LAURA%20FINHOLDT%20LOPES.pdf
# Status ok!
#
# a[data-clk-atid="XSdTCOjNGdUJ"]
# KeyboardInterrupt

# %%
url_presente_dinamico = driver.current_url
print(url_presente_dinamico)
print(url_presente)
